# %% [markdown]
# # S3 특정 폴더를 Code Whisperer 커스터마이징

# %%
import sagemaker

bucket_name = sagemaker.Session().default_bucket()
print (f'bucket_name: {bucket_name}')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# bucket_name: sagemaker-us-east-1-057716757052

# %%
! aws s3 ls s3://sagemaker-us-east-1-057716757052/CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/byoc --recursive
# Out:
# 2024-04-04 00:44:09          0 CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/byoc/Readme.md
# 2024-04-04 00:44:08      28808 CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/byoc/hello_docker.ipynb
# 2024-04-04 00:44:10      28999 CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/byoc/inf_toolkit_bring_your_own/01_Creating a Classifier Container.ipynb
# 2024-04-04 00:44:11       4265 CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/byoc/inf_toolkit_bring_your_own/02_Testing our local model server.ipynb
# 2024-04-04 00:44:09       1431 CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/byoc/inf_toolkit_bring_your_own/build_and_push.sh
# 2024-04-04 00:44:26       1522 CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/byoc/scikit_bring_your_own/container/Dockerfile
# ...

# %%
! aws s3 ls  s3://sagemaker-us-east-1-057716757052/CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/recommendation/Neural-Collaborative-Filtering-On-SageMaker --recursive --human-readable --summarize
# Out:
# 2024-04-04 00:50:20    3.3 KiB CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/recommendation/Neural-Collaborative-Filtering-On-SageMaker/1_Train/0.0.Setup-Environment.ipynb
# 2024-04-04 00:50:23   35.7 KiB CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/recommendation/Neural-Collaborative-Filtering-On-SageMaker/1_Train/1.1.NCF-Train-Scratch.ipynb
# 2024-04-04 00:50:18   17.9 KiB CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/recommendation/Neural-Collaborative-Filtering-On-SageMaker/1_Train/1.2.NCF-Train_Local_Script_Mode.ipynb
# 2024-04-04 00:50:19   18.9 KiB CodeWhisperer/data/240404-AWS-KR-Workshop-Code/aws-ai-ml-workshop-kr/sagemaker/recommendation/Neural-Collaborative-Filtering-On-SageMaker/1_Train/1.3.NCF-Train_Horovod.ipynb
# ...
